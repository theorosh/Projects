# %% [markdown]
# ***Importing Nessessary Libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *Reading data*

# %%
df=pd.read_csv('/content/drive/MyDrive/bladder.csv')

# %% [markdown]
# *EDA*

# %%
df.head()
# Out:
#    A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  AB000449_at  \
# 0       24.4         10.5         30.4         30.8         66.0         94.1
# 1       24.8         29.9         65.1        174.4         40.4         26.2
# 2        1.5          8.5         66.5        255.7        118.9         80.6
# 3       15.4          4.9         20.3        388.4        116.6         70.2
# 4       45.9         12.4        249.6         85.8         12.6         21.1
#
#    AB000450_at  AB000460_at  AB000462_at  AB000464_at  ...  Z84721_cds2_at  \
# 0        109.3        361.8         10.5        121.7  ...          1798.1
# 1         46.6        362.6         28.5        116.5  ...           770.1
# 2         68.4        310.5         10.7         71.9  ...           427.1
# 3        101.6        281.7         29.4         87.6  ...          1189.3
# 4         22.5        291.3          3.0        128.5  ...          1017.0
#
# ...

# %%
df.shape
# Out:
# (40, 5726)

# %%
df.describe()
# Out:
#         A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# count   40.000000    40.000000    40.000000     40.00000    40.000000
# mean    40.937500    13.005000   122.367500    302.24500    56.135000
# std     52.060245    15.996249   148.610148    199.23749    50.591185
# min    -36.500000   -10.300000     7.300000     30.80000   -50.300000
# 25%     10.300000     4.000000    32.225000    165.77500    25.800000
# 50%     26.200000     8.300000    82.050000    277.05000    43.350000
# 75%     50.925000    16.525000   176.425000    393.70000    78.775000
# max    276.100000    72.400000   880.300000    894.90000   170.000000
#
#        AB000449_at  AB000450_at  AB000460_at  AB000462_at  AB000464_at  ...  \
# count    40.000000    40.000000    40.000000    40.000000    40.000000  ...
# mean     44.017500    64.337500   399.255000    27.162500   103.267500  ...
# std      30.661978    39.304829   384.199918    55.315546    68.636917  ...
# ...

# %%
corr= df.corr()

# %%
df.tail()
# Out:
#     A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# 35       58.0          2.6         81.6        347.3         40.1
# 36      107.5         15.9        209.8        294.6        -17.4
# 37       32.9         72.4         85.1        463.1        116.5
# 38       -2.4         52.2        264.1        210.8         63.8
# 39       89.2          3.1        334.2        154.2         92.2
#
#     AB000449_at  AB000450_at  AB000460_at  AB000462_at  AB000464_at  ...  \
# 35         49.7         66.0        428.0          6.0         71.1  ...
# 36        156.9         83.7       2722.9        343.9        402.6  ...
# 37         23.4         32.0        422.7         59.5        101.6  ...
# 38         43.9         51.5        360.5          7.3         55.5  ...
# 39         52.9         31.2        279.9         13.2        128.9  ...
#
#     Z84721_cds2_at  Z86000_at  Z93784_at  Z94753_s_at  Z95624_at  Z96810_at  \
# ...

# %%
df['class'].value_counts()
# Out:
# Ta     19
# T1     11
# T2+    10
# Name: class, dtype: int64

# %%
df.dtypes
# Out:
# A28102_at         float64
# AB000114_at       float64
# AB000115_at       float64
# AB000220_at       float64
# AB000409_at       float64
#                    ...
# Z96810_at         float64
# Z97054_xpt2_at    float64
# Z97074_at         float64
# sample             object
# class              object
# Length: 5726, dtype: object

# %%
df.drop('sample',axis=1)
# Out:
#     A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# 0        24.4         10.5         30.4         30.8         66.0
# 1        24.8         29.9         65.1        174.4         40.4
# 2         1.5          8.5         66.5        255.7        118.9
# 3        15.4          4.9         20.3        388.4        116.6
# 4        45.9         12.4        249.6         85.8         12.6
# 5       -18.2         -0.4        198.8         78.9         76.6
# 6        10.0          4.3         15.2        360.3         85.3
# 7        85.8         16.4        130.6        223.6         28.7
# 8        57.2         21.1         53.9         81.6         62.3
# 9        38.7         16.9         94.9        276.6         61.6
# 10       47.9         20.0        242.1        135.1         45.7
# 11       22.1          6.0        101.5        375.9         74.1
# 12       39.9         10.4        193.2        400.6         26.1
# ...

# %%
x=df.drop(['class'],axis=1)
Y=df['class']

# %%
x
# Out:
#     A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# 0        24.4         10.5         30.4         30.8         66.0
# 1        24.8         29.9         65.1        174.4         40.4
# 2         1.5          8.5         66.5        255.7        118.9
# 3        15.4          4.9         20.3        388.4        116.6
# 4        45.9         12.4        249.6         85.8         12.6
# 5       -18.2         -0.4        198.8         78.9         76.6
# 6        10.0          4.3         15.2        360.3         85.3
# 7        85.8         16.4        130.6        223.6         28.7
# 8        57.2         21.1         53.9         81.6         62.3
# 9        38.7         16.9         94.9        276.6         61.6
# 10       47.9         20.0        242.1        135.1         45.7
# 11       22.1          6.0        101.5        375.9         74.1
# 12       39.9         10.4        193.2        400.6         26.1
# ...

# %%
Y
# Out:
# 0     T2+
# 1     T2+
# 2      Ta
# 3      Ta
# 4     T2+
# 5     T2+
# 6      Ta
# 7     T2+
# 8     T2+
# 9      Ta
# 10    T2+
# 11     Ta
# 12     Ta
# 13     Ta
# 14     T1
# 15     Ta
# 16     Ta
# 17     Ta
# 18     Ta
# 19     T1
# 20     T1
# 21    T2+
# 22     Ta
# 23     T1
# 24     T1
# 25     Ta
# 26     Ta
# 27     Ta
# 28    T2+
# 29     Ta
# 30     Ta
# 31     Ta
# 32     Ta
# 33    T2+
# 34     T1
# 35     T1
# 36     T1
# 37     T1
# 38     T1
# 39     T1
# Name: class, dtype: object

# %%
df.isnull().sum()
# Out:
# A28102_at         0
# AB000114_at       0
# AB000115_at       0
# AB000220_at       0
# AB000409_at       0
#                  ..
# Z96810_at         0
# Z97054_xpt2_at    0
# Z97074_at         0
# sample            0
# class             0
# Length: 5726, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x ='class', hue = "class", data = df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
encoder.fit(Y)
y=encoder.transform(Y)

# %%
y
# Out:
# array([1, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 0, 0, 1,
#        2, 0, 0, 2, 2, 2, 1, 2, 2, 2, 2, 1, 0, 0, 0, 0, 0, 0])

# %% [markdown]
# *Splitting Train and Test*

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train= X_train.drop(['sample'],axis=1)

# %%
x_train
# Out:
#     A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# 3        15.4          4.9         20.3        388.4        116.6
# 6        10.0          4.3         15.2        360.3         85.3
# 33       46.5         39.7         34.3        260.8        159.2
# 0        24.4         10.5         30.4         30.8         66.0
# 14       52.5         -1.1         29.8         61.2         -9.3
# 11       22.1          6.0        101.5        375.9         74.1
# 18        0.4          7.3         29.8        510.3         41.0
# 39       89.2          3.1        334.2        154.2         92.2
# 5       -18.2         -0.4        198.8         78.9         76.6
# 25       24.9         12.7         32.7        188.7         -8.5
# 4        45.9         12.4        249.6         85.8         12.6
# 38       -2.4         52.2        264.1        210.8         63.8
# 36      107.5         15.9        209.8        294.6        -17.4
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)

# %%
x_test= x_test.drop(['sample'],axis=1)

# %% [markdown]
# *XG Boost Classifier*

# %%
from xgboost import XGBClassifier
model1=XGBClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
y_pred=model1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
print("Accuracy score for XGB classifier:",score*100)
# Out:
# Accuracy score for XGB classifier: 60.0

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
plot_confusion_matrix(model1,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.00      0.00      0.00         0
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.60        10
#    macro avg       0.56      0.40      0.46        10
# weighted avg       0.83      0.60      0.69        10
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(n_estimators=150)
gbc.fit(x_train,y_train)
y_predgbc = gbc.predict(x_test)

print(classification_report(y_test,y_predgbc))
plot_confusion_matrix(gbc,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         3
#            1       0.50      0.33      0.40         3
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.70        10
#    macro avg       0.67      0.67      0.66        10
# weighted avg       0.70      0.70      0.69        10
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
selected_feat_full=x.columns

# %%
selected_feat_full[1]
# Out:
# 'AB000114_at'

# %%
from scipy.stats import pearsonr

# %%
new_list=[]
for i in range(0,5724):
    corr, _ = pearsonr(x[selected_feat_full[i]], y)
    print('Pearsons correlation: %.3f' % corr,[selected_feat_full[i]])
    new_list.append(corr)
# Out:
# Streaming output truncated to the last 5000 lines.
# Pearsons correlation: 0.593 ['D87120_at']
# Pearsons correlation: 0.493 ['D87127_at']
# Pearsons correlation: 0.182 ['D87258_at']
# Pearsons correlation: 0.318 ['D87292_at']
# Pearsons correlation: 0.614 ['D87328_at']
# Pearsons correlation: -0.058 ['D87432_at']
# Pearsons correlation: -0.019 ['D87433_at']
# Pearsons correlation: -0.155 ['D87434_at']
# Pearsons correlation: -0.596 ['D87435_at']
# Pearsons correlation: -0.049 ['D87436_at']
# Pearsons correlation: -0.257 ['D87437_at']
# Pearsons correlation: 0.124 ['D87438_at']
# Pearsons correlation: 0.264 ['D87440_at']
# Pearsons correlation: -0.541 ['D87442_at']
# Pearsons correlation: 0.662 ['D87443_at']
# Pearsons correlation: 0.345 ['D87444_at']
# Pearsons correlation: 0.174 ['D87445_at']
# Pearsons correlation: 0.548 ['D87446_at']
# Pearsons correlation: 0.227 ['D87447_at']
# Pearsons correlation: 0.271 ['D87448_at']
# Pearsons correlation: 0.114 ['D87449_at']
# ...

# %%
len(new_list)
# Out:
# 5724

# %%
# High corr feature
max(new_list)
# Out:
# 0.7607204768666632

# %%
x[selected_feat_full].corr()
# Out:
#                 A28102_at  AB000114_at  AB000115_at  AB000220_at  AB000409_at  \
# A28102_at        1.000000     0.000734    -0.083077    -0.048052    -0.143745
# AB000114_at      0.000734     1.000000    -0.049704     0.063750     0.191162
# AB000115_at     -0.083077    -0.049704     1.000000    -0.022491    -0.179198
# AB000220_at     -0.048052     0.063750    -0.022491     1.000000     0.328002
# AB000409_at     -0.143745     0.191162    -0.179198     0.328002     1.000000
# ...                   ...          ...          ...          ...          ...
# Z94753_s_at     -0.087895     0.004250    -0.001475     0.359586    -0.067641
# Z95624_at        0.099444     0.100346     0.168032    -0.329164    -0.190403
# Z96810_at       -0.002552    -0.035149    -0.215761     0.184148     0.319131
# Z97054_xpt2_at  -0.288097    -0.165187    -0.211745     0.029896     0.260526
# Z97074_at        0.043942    -0.024575     0.052280     0.063708     0.395220
#
# ...

# %% [markdown]
# *Feature selection with model*

# %%
from sklearn.svm import LinearSVC

from sklearn.feature_selection import SelectFromModel


lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(x_train, y_train)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(x_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
X_new.shape
# Out:
# (30, 54)

# %%
model.get_support()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
len(model.get_feature_names_out(x_train.columns))
# Out:
# 54

# %%
Feature_selected_with_model=model.get_feature_names_out(x_train.columns)

# %%
Feature_selected_with_model
# Out:
# array(['AFFX-HSAC07/X00351_M_at', 'D13413_rna1_s_at', 'D30655_at',
#        'D45370_at', 'D49824_s_at', 'D78134_at', 'D87953_at',
#        'HG2788-HT2896_at', 'HG3214-HT3391_at', 'J03242_s_at',
#        'J04152_rna1_s_at', 'L06499_at', 'L26247_at', 'M11147_at',
#        'M11313_s_at', 'M13955_at', 'M17885_at', 'M18000_at', 'M18728_at',
#        'M23613_at', 'M25079_s_at', 'M26730_s_at', 'M32053_at',
#        'M33336_at', 'M33552_at', 'M35878_at', 'M63379_at', 'M80563_at',
#        'M94250_at', 'M94856_at', 'S54005_s_at', 'S73591_at', 'U03057_at',
#        'U14969_at', 'U31875_at', 'U43901_rna1_s_at', 'U46499_at',
#        'U72649_at', 'U90878_at', 'V00594_at', 'V00594_s_at', 'X02152_at',
#        'X12671_rna1_at', 'X17206_at', 'X51441_s_at', 'X57809_s_at',
#        'X65614_at', 'X68314_at', 'X82456_at', 'X83618_at', 'Y00503_at',
#        'Y00705_at', 'Z23090_at', 'Z28407_at'], dtype=object)

# %%
max(Feature_selected_with_model)
# Out:
# 'Z28407_at'

# %% [markdown]
# *Feature selection with ANOVA test*

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
select = SelectKBest(f_classif,k=50)
z = select.fit_transform(x_train,y_train)
 
print("After selecting best 50 features:", z.shape)
# Out:
# After selecting best 50 features: (30, 50)

# %%
select.get_feature_names_out()
# Out:
# array(['AFFX-HUMGAPDH/M33197_3_at', 'AFFX-HUMGAPDH/M33197_M_at',
#        'D13413_rna1_s_at', 'D49396_at', 'D78361_at', 'HG2788-HT2896_at',
#        'HG2815-HT4023_s_at', 'HG2873-HT3017_at', 'HG3214-HT3391_at',
#        'HG3364-HT3541_at', 'HG3527-HT3721_f_at', 'L04483_s_at',
#        'L06499_at', 'L11566_at', 'L19527_at', 'L19686_rna1_at',
#        'L19872_at', 'M11147_at', 'M13934_cds2_at', 'M14199_s_at',
#        'M17733_at', 'M17885_at', 'M17886_at', 'M32405_at', 'M33336_at',
#        'M36072_at', 'M60854_at', 'S77393_at', 'U06155_s_at', 'U14969_at',
#        'U14972_at', 'U14973_at', 'U43901_rna1_s_at', 'X01677_f_at',
#        'X06617_at', 'X17206_at', 'X55715_at', 'X56932_at',
#        'X56997_rna1_at', 'X59710_at', 'X65614_at', 'X69150_at',
#        'X73460_at', 'X80822_at', 'X98172_at', 'Z12962_at', 'Z23090_at',
#        'Z26876_at', 'Z28407_at', 'Z49148_s_at'], dtype=object)

# %% [markdown]
# Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
BClassifier=BaggingClassifier(n_estimators=50)
BClassifier.fit(x_train,y_train)
y_pred_BClassifier=BClassifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
print(classification_report(y_pred,y_test))
plot_confusion_matrix(BClassifier,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.00      0.00      0.00         0
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.60        10
#    macro avg       0.56      0.40      0.46        10
# weighted avg       0.83      0.60      0.69        10
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# Naive Bayers Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nbc=GaussianNB()
nbc.fit(x_train,y_train)
y_prednbc = nbc.predict(x_test)

print(classification_report(y_test,y_prednbc))
plot_confusion_matrix(nbc,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33         3
#            1       0.50      0.33      0.40         3
#            2       0.60      0.75      0.67         4
#
#     accuracy                           0.50        10
#    macro avg       0.48      0.47      0.47        10
# weighted avg       0.49      0.50      0.49        10
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ***Reducing dimention using PCA***

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components= 1)
pca.fit(x_train)
# Out:
# PCA(n_components=1)

# %%
x_pca_train = pca.transform(x_train)
x_pca_test = pca.transform(x_test)

# %%
x_pca_train.shape
# Out:
# (30, 1)

# %%
x_pca_train
# Out:
# array([[-12223.04821771],
#        [-22205.69919051],
#        [ 33318.70575104],
#        [  8662.46023867],
#        [ 10700.01035396],
#        [-18943.04684451],
#        [-19529.70365303],
#        [ 18075.69826169],
#        [  8637.05124689],
#        [ -2205.11381529],
#        [  1280.83939356],
#        [  3941.22958545],
#        [ 30521.66532335],
#        [  2766.54894052],
#        [  4479.3629034 ],
#        [-10080.23269262],
#        [ 21204.98924175],
#        [ 23863.71037462],
#        [-23467.14366933],
#        [-13033.96216223],
#        [-19774.8856946 ],
#        [ -5682.20185515],
#        [ 14777.65946544],
#        [ 15742.06040691],
#        [  9710.78595794],
#        [-19204.1704851 ],
#        [-15135.80769051],
#        [-22310.06824865],
#        [ 16435.39856352],
#        [-20323.09178947]])

# %%
y
# Out:
# array([1, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 0, 0, 1,
#        2, 0, 0, 2, 2, 2, 1, 2, 2, 2, 2, 1, 0, 0, 0, 0, 0, 0])

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model=LogisticRegression(multi_class='multinomial',solver='lbfgs')
model.fit(x_train,y_train)
y_pred_lr =model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.00      0.00      0.00         0
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.60        10
#    macro avg       0.56      0.40      0.46        10
# weighted avg       0.83      0.60      0.69        10
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='entropy')
dtc.fit(x_pca_train, y_train)
y_predDT = dtc.predict(x_pca_test)

# %%
print(accuracy_score(y_pred,y_test)*100)
# Out:
# 60.0

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
print(classification_report(y_pred,y_test))
plot_confusion_matrix(dtc,x_pca_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.00      0.00      0.00         0
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.60        10
#    macro avg       0.56      0.40      0.46        10
# weighted avg       0.83      0.60      0.69        10
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_pca_train, y_train)
y_predknn = knn.predict(x_pca_test)
y_predict_proba_knn = knn.predict_proba(x_pca_test)

print(classification_report(y_test, y_predknn))
plot_confusion_matrix(knn,x_pca_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#            2       1.00      0.75      0.86         4
#
#     accuracy                           0.60        10
#    macro avg       0.50      0.58      0.51        10
# weighted avg       0.55      0.60      0.54        10
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(accuracy_score(y_predknn,y_test)*100)
# Out:
# 60.0

# %% [markdown]
# Random forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, criterion="entropy")
rf.fit(x_train, y_train)
y_predrf = rf.predict(x_test) 
y_predict_proba_rf = rf.predict_proba(x_test)

print(classification_report(y_test, y_predrf))
plot_confusion_matrix(rf,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         3
#            1       1.00      0.33      0.50         3
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.80        10
#    macro avg       0.87      0.78      0.75        10
# weighted avg       0.88      0.80      0.78        10
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(accuracy_score(y_predrf,y_test)*100)
# Out:
# 80.0
